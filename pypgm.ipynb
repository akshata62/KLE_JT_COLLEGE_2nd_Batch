# %%
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# python 2nd program

# %%
print("*"*3)
# Out:
# ***

# %%
print("*"*3,sep="\n")
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
name=("akshata")
print(name)
# Out:
# akshata
